# %%
# !pip install -r '/kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt'
# Out:
# Collecting axial-positional-embedding==0.3.12 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 1))
#   Downloading axial_positional_embedding-0.3.12-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 2)) (0.12.1)
# Requirement already satisfied: einops==0.8.2 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 3)) (0.8.2)
# Requirement already satisfied: joblib==1.5.3 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 4)) (1.5.3)
# Collecting kiwisolver==1.4.9 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 5))
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting local-attention==1.11.2 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 6))
#   Downloading local_attention-1.11.2-py3-none-any.whl.metadata (929 bytes)
# Requirement already satisfied: matplotlib==3.10.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 7)) (3.10.0)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 8)) (1.3.0)
# Collecting numpy==2.0.2 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 9))
#   Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.11.3.6 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 10))
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 11))
#   Downloading nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 12))
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu11==9.10.2.21 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 13))
#   Downloading nvidia_cudnn_cu11-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting packaging==26.0 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 14))
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas==2.3.3 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 15)) (2.3.3)
# Collecting patool==4.0.4 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 16))
#   Downloading patool-4.0.4-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: patsy==1.0.2 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 17)) (1.0.2)
# Requirement already satisfied: pillow==11.3.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 18)) (11.3.0)
# Requirement already satisfied: pip==24.1.2 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 19)) (24.1.2)
# Collecting product-key-memory==0.3.0 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 20))
#   Downloading product_key_memory-0.3.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pyparsing==3.3.2 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 21)) (3.3.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 22)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 23)) (2025.2)
# Collecting reformer-pytorch==1.4.4 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 24))
#   Downloading reformer_pytorch-1.4.4-py3-none-any.whl.metadata (764 bytes)
# Collecting scikit-base==0.13.1 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 25))
#   Downloading scikit_base-0.13.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 26)) (1.6.1)
# Requirement already satisfied: scipy==1.16.3 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 27)) (1.16.3)
# Requirement already satisfied: setuptools==75.2.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 28)) (75.2.0)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 29)) (1.17.0)
# Collecting sktime==0.40.1 (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 30))
#   Downloading sktime-0.40.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: statsmodels==0.14.6 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 31)) (0.14.6)
# Requirement already satisfied: sympy==1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 32)) (1.14.0)
# Requirement already satisfied: threadpoolctl==3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 33)) (3.6.0)
# Requirement already satisfied: torch==2.10.0+cu128 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (2.10.0+cu128)
# Requirement already satisfied: tqdm==4.67.3 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 35)) (4.67.3)
# Requirement already satisfied: typing_extensions==4.15.0 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 36)) (4.15.0)
# Requirement already satisfied: wheel==0.46.3 in /usr/local/lib/python3.12/dist-packages (from -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 37)) (0.46.3)
# Collecting hyper-connections>=0.1.8 (from local-attention==1.11.2->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 6))
#   Downloading hyper_connections-0.4.11-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.0->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 7)) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.0->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 7)) (4.62.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.3->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 15)) (2026.1)
# Collecting colt5-attention>=0.10.14 (from product-key-memory==0.3.0->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 20))
#   Downloading CoLT5_attention-0.11.1-py3-none-any.whl.metadata (737 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (3.25.2)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (2025.3.0)
# Collecting cuda-bindings==12.9.4 (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34))
#   Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (1.5.4)
# Collecting torch-einops-utils>=0.0.20 (from hyper-connections>=0.1.8->local-attention==1.11.2->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 6))
#   Downloading torch_einops_utils-0.1.4-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.10.0+cu128->-r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP/requirements_TimeKAN.txt (line 34)) (3.0.3)
# Downloading axial_positional_embedding-0.3.12-py3-none-any.whl (6.7 kB)
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 23.3 MB/s eta 0:00:00
# Downloading local_attention-1.11.2-py3-none-any.whl (9.5 kB)
# Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 85.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 50.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 35.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (397.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 MB 4.0 MB/s eta 0:00:00
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 2.2 MB/s eta 0:00:00
# Downloading patool-4.0.4-py2.py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 5.5 MB/s eta 0:00:00
# Downloading product_key_memory-0.3.0-py3-none-any.whl (8.3 kB)
# Downloading reformer_pytorch-1.4.4-py3-none-any.whl (16 kB)
# Downloading scikit_base-0.13.1-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.8/159.8 kB 12.6 MB/s eta 0:00:00
# Downloading sktime-0.40.1-py3-none-any.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 44.7 MB/s eta 0:00:00
# Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 70.6 MB/s eta 0:00:00
# Downloading CoLT5_attention-0.11.1-py3-none-any.whl (18 kB)
# Downloading hyper_connections-0.4.11-py3-none-any.whl (29 kB)
# Downloading torch_einops_utils-0.1.4-py3-none-any.whl (8.2 kB)
# Installing collected packages: scikit-base, patool, packaging, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, kiwisolver, cuda-bindings, nvidia-cudnn-cu11, torch-einops-utils, sktime, axial-positional-embedding, hyper-connections, local-attention, colt5-attention, product-key-memory, reformer-pytorch
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.6
#     Uninstalling numpy-2.4.6:
#       Successfully uninstalled numpy-2.4.6
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.5.0
#     Uninstalling kiwisolver-1.5.0:
#       Successfully uninstalled kiwisolver-1.5.0
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# ydata-profiling 4.18.4 requires numba<0.63,>=0.60, but you have numba 0.65.1 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Successfully installed axial-positional-embedding-0.3.12 colt5-attention-0.11.1 cuda-bindings-12.9.4 hyper-connections-0.4.11 kiwisolver-1.4.9 local-attention-1.11.2 numpy-2.0.2 nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.10.2.21 packaging-26.0 patool-4.0.4 product-key-memory-0.3.0 reformer-pytorch-1.4.4 scikit-base-0.13.1 sktime-0.40.1 torch-einops-utils-0.1.4

# %%
import os

# 1. Copy toàn bộ thư mục code sang /kaggle/working/ (nơi có quyền ghi/sửa)
# !cp -r /kaggle/input/datasets/ht2004/ca-mlp/CA-MLP /kaggle/working/JD-KAN_writable

# 2. Chuyển thư mục làm việc sang thư mục vừa copy
os.chdir('/kaggle/working/JD-KAN_writable')

# Kiểm tra xem đã đúng thư mục chưa (Đường dẫn hiện tại sẽ là /kaggle/working/...)
# !pwd
# !ls
# Out:
# /kaggle/working/JD-KAN_writable
# checkpoints    exp		   KQ	   README.md		     run.py
# data_provider  experiment_figures  layers  requirements_TimeKAN.txt  scripts
# dataset        experiment_scripts  models  requirements.txt	     utils

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/Look_back_window/etth2.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/Look_back_window/etth2.sh

# 3. Chạy script
# !./scripts/Look_back_window/etth2.sh
# Out:
# Running with seq_len=48
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_48_96         Model:              CA_MLP
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            48                  Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       100                 Batch Size:         32
#   Patience:           10                  Learning Rate:      0.001
#   Des:                Exp_CA_MLP_researchingLoss:               MSE
#   Lradj:              cosine              Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: CA_MLP ...
# >>>>>>>start training : long_term_forecast_ETTh2_48_96_CA_MLP_ETTh2_ftM_sl48_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.9631122
# 	speed: 0.0972s/iter; left time: 2574.6888s
# 	iters: 200, epoch: 1 | loss: 0.4650056
# 	speed: 0.0109s/iter; left time: 287.8296s
# Epoch: 1 cost time: 5.162113428115845
# Epoch: 1, Steps: 266 | Train Loss: 0.5130782 Vali Loss: 0.2659614 Test Loss: 0.3468887
# Validation loss decreased (inf --> 0.265961).  Saving model ...
# Updating learning rate to 0.0009997532801828658
# 	iters: 100, epoch: 2 | loss: 0.7995482
# 	speed: 0.0363s/iter; left time: 952.7703s
# 	iters: 200, epoch: 2 | loss: 0.5360458
# 	speed: 0.0108s/iter; left time: 281.6296s
# Epoch: 2 cost time: 3.125375270843506
# Epoch: 2, Steps: 266 | Train Loss: 0.4732325 Vali Loss: 0.2292752 Test Loss: 0.3079662
# Validation loss decreased (0.265961 --> 0.229275).  Saving model ...
# Updating learning rate to 0.0009990133642141358
# 	iters: 100, epoch: 3 | loss: 0.3059212
# 	speed: 0.0377s/iter; left time: 979.6826s
# 	iters: 200, epoch: 3 | loss: 0.3519295
# 	speed: 0.0104s/iter; left time: 269.5724s
# Epoch: 3 cost time: 3.219108819961548
# Epoch: 3, Steps: 266 | Train Loss: 0.4519135 Vali Loss: 0.2297288 Test Loss: 0.3069005
# EarlyStopping counter: 1 out of 10
# Updating learning rate to
# Epoch: 24, Steps: 266 | Train Loss: 0.4265152 Vali Loss: 0.2364535 Test Loss: 0.3108994
# EarlyStopping counter: 9 out of 10
# Updating learning rate to 0.0008644843137107057
# 	iters: 100, epoch: 25 | loss: 0.3707962
# 	speed: 0.0362s/iter; left time: 727.7975s
# 	iters: 200, epoch: 25 | loss: 0.4369992
# 	speed: 0.0107s/iter; left time: 215.1433s
# Epoch: 25 cost time: 3.0987911224365234
# Epoch: 25, Steps: 266 | Train Loss: 0.4239449 Vali Loss: 0.2261317 Test Loss: 0.3041293
# EarlyStopping counter: 10 out of 10
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh2_48_96_CA_MLP_ETTh2_ftM_sl48_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
#
# [PERFORMANCE] Total Inference Time: 0.2857 s
# [PERFORMANCE] Avg Inference Time / Batch: 0.003247 s
# [PERFORMANCE] Peak GPU Memory Allocated: 23.09 MB
#
# mse:0.3000534176826477, mae:0.3442128896713257, dtw:Not calculated
# Running with seq_len=96
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_96_96         Model:              CA_MLP
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       100                 Batch Size:         32
#   Patience:           10                  Learning Rate:      0.001
#   Des:                Exp_CA_MLP_researchingLoss:               MSE
#   Lradj:              cosine              Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: CA_MLP ...
# >>>>>>>start training : long_term_forecast_ETTh2_96_96_CA_MLP_ETTh2_ftM_sl96_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.6879446
# 	speed: 0.0312s/iter; left time: 823.8796s
# 	iters: 200, epoch: 1 | loss: 0.4062635
# 	speed: 0.0104s/iter; left time: 272.8765s
# Epoch: 1 cost time: 3.6416289806365967
# Epoch: 1, Steps: 265 | Train Loss: 0.5218506 Vali Loss: 0.2780630 Test Loss: 0.3492413
# Validation loss decreased (inf --> 0.278063).  Saving model ...
# EarlyStopping counter: 6 out of 10
# Updating learning rate to 0.0009455032620941839
# 	iters: 100, epoch: 16 | loss: 0.3824827
# 	speed: 0.0364s/iter; left time: 816.3134s
# 	iters: 200, epoch: 16 | loss: 0.9215651
# 	speed: 0.0103s/iter; left time: 228.9006s
# Epoch: 16 cost time: 3.0453712940216064
# Epoch: 16, Steps: 265 | Train Loss: 0.4037006 Vali Loss: 0.2123687 Test Loss: 0.2953386
# EarlyStopping counter: 7 out of 10
# Updating learning rate to 0.0009381533400219318
# 	iters: 100, epoch: 17 | loss: 0.2106461
# 	speed: 0.0368s/iter; left time: 815.9041s
# 	iters: 200, epoch: 17 | loss: 0.6471847
# 	speed: 0.0106s/iter; left time: 233.0735s
# Epoch: 17 cost time: 3.072920322418213
# Epoch: 17, Steps: 265 | Train Loss: 0.4019587 Vali Loss: 0.2160948 Test Loss: 0.2924784
# EarlyStopping counter: 8 out of 10
# Updating learning rate to 0.0009303710135019718
# 	iters: 100, epoch: 18 | loss: 0.6042283
# 	speed: 0.0365s/iter; left time: 799.2003s
# 	iters: 200, epoch: 18 | loss: 0.2449192
# 	speed: 0.0106s/iter; left time: 231.5514s
# Epoch: 18 cost time: 3.1346700191497803
# Epoch: 18, Steps: 265 | Train Loss: 0.4010606 Vali Loss: 0.2160673 Test Loss: 0.2955950
# EarlyStopping counter: 9 out of 10
# Updating learning rate to 0.0009221639627510075
# 	iters: 100, epoch: 19 | loss: 0.2817674
# 	speed: 0.0372s/iter; left time: 804.7223s
# 	iters: 200, epoch: 19 | loss: 0.3306265
# 	speed: 0.0104s/iter; left time: 223.6110s
# Epoch: 19 cost time: 3.0985209941864014
# Epoch: 19, Steps: 265 | Train Loss: 0.4015273 Vali Loss: 0.2112361 Test Loss: 0.2981856
# EarlyStopping counter: 10 out of 10
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh2_96_96_CA_MLP_ETTh2_ftM_sl96_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
#
# [PERFORMANCE] Total Inference Time: 0.3437 s
# [PERFORMANCE] Avg Inference Time / Batch: 0.003905 s
# [PERFORMANCE] Peak GPU Memory Allocated: 28.48 MB
#
# mse:0.2938849627971649, mae:0.3393665552139282, dtw:Not calculated
# Running with seq_len=192
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_192_96        Model:              CA_MLP
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            192                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       100                 Batch Size:         32
#   Patience:           10                  Learning Rate:      0.001
#   Des:                Exp_CA_MLP_researchingLoss:               MSE
#   Lradj:              cosine              Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: CA_MLP ...
# >>>>>>>start training : long_term_forecast_ETTh2_192_96_CA_MLP_ETTh2_ftM_sl192_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4395784
# 	speed: 0.0339s/iter; left time: 885.6235s
# 	iters: 200, epoch: 1 | loss: 0.3618500
# 	speed: 0.0121s/iter; left time: 314.5280s
# Epoch: 1 cost time: 4.198000907897949
# Epoch: 1, Steps: 262 | Train Loss: 0.5438657 Vali Loss: 0.2884677 Test Loss: 0.3716567
# Validation loss decreased (inf --> 0.288468).  Saving model ...
# Updating learning rate to 0.0009997532801828658
# 	iters: 100, epoch: 2 | loss: 0.2945037
# 	speed: 0.0423s/iter; left time: 1093.0938s
# 	iters: 200, epoch: 2 | loss: 0.6582683
# 	speed: 0.0125s/iter; left time: 323.0040s
# Epoch: 2 cost time: 3.5675048828125
# Epoch: 2, Steps: 262 | Train Loss: 0.4342495 Vali Loss: 0.2218276 Test Loss: 0.2930119
# Validation loss decreased (0.288468 --> 0.221828).  Saving model ...
# Updating learning rate to 0.0009990133642141358
# 	iters: 100, epoch: 3 | loss: 0.3137979
# 	speed: 0.0420s/iter; left time: 1075.1852s
# 	iters: 200, epoch: 3 | loss: 0.2666668
# 	speed: 0.0128s/iter; left time: 327.1142s
# Epoch: 3 cost time: 3.5537099838256836
# Epoch: 3, Steps: 262 | Train Loss: 0.4068461 Vali Loss: 0.2169224 Test Loss: 0.2917036
# Validation loss decreased (0.221828 --> 0.216922).  Saving model ...
# Updating learning rate to 0.00099778098230154
# 	iters: 100, epoch: 4 | loss: 0.3937551
# 	speed: 0.0421s/iter; left time: 1065.8530s
# 	iters: 200, epoch: 4 | loss: 0.2505577
# 	speed: 0.0123s/iter; left time: 310.4586s
# Epoch: 4 cost time: 3.5203986167907715
# Epoch: 4, Steps: 262 | Train Loss: 0.4083831 Vali Loss: 0.2136332 Test Loss: 0.2994028
# Validation loss decreased (0.216922 --> 0.213633).  Saving model ...
# Updating learning rate to 0.000996057350657239
# 	iters: 100, epoch: 5 | loss: 0.3918999
# 	speed: 0.0415s/iter; left time: 1040.3165s
# 	iters: 200, epoch: 5 | loss: 0.4420131
# 	speed: 0.0124s/iter; left time: 308.5152s
# Epoch: 5 cost time: 3.5288803577423096
# Epoch: 5, Steps: 262 | Train Loss: 0.4125065 Vali Loss: 0.2117456 Test Loss: 0.2887416
# Validation loss decreased (0.213633 --> 0.211746).  Saving model ...
# Updating learning rate to 0.0009938441702975688
# 	iters: 100, epoch: 6 | loss: 0.2662063
# 	speed: 0.0422s/iter; left time: 1045.5748s
# 	iters: 200, epoch: 6 | loss: 0.6280940
# 	speed: 0.0121s/iter; left time: 299.9608s
# Epoch: 6 cost time: 3.5234334468841553
# Epoch: 6, Steps: 262 | Train Loss: 0.3940479 Vali Loss: 0.2198751 Test Loss: 0.2896050
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 0.0009911436253643444
# 	iters: 100, epoch: 7 | loss: 0.3249772
# 	speed: 0.0425s/iter; left time: 1043.3746s
# 	iters: 200, epoch: 7 | loss: 0.3140107
# 	speed: 0.0121s/iter; left time: 295.5174s
# Epoch: 7 cost time: 3.5422651767730713
# Epoch: 7, Steps: 262 | Train Loss: 0.3945446 Vali Loss: 0.2107549 Test Loss: 0.2868788
# Validation loss decreased (0.211746 --> 0.210755).  Saving model ...
# Updating learning rate to 0.0009879583809693738
# 	iters: 100, epoch: 8 | loss: 0.4743150
# 	speed: 0.0421s/iter; left time: 1022.3040s
# 	iters: 200, epoch: 8 | loss: 0.4501599
# 	speed: 0.0120s/iter; left time: 289.8927s
# Epoch: 8 cost time: 3.480099678039551
# Epoch: 8, Steps: 262 | Train Loss: 0.3950267 Vali Loss: 0.2137834 Test Loss: 0.2916293
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 0.0009842915805643156
# 	iters: 100, epoch: 9 | loss: 1.0430965
# 	speed: 0.0421s/iter; left time: 1009.7007s
# 	iters: 200, epoch: 9 | loss: 0.4913369
# 	speed: 0.0122s/iter; left time: 290.8469s
# Epoch: 9 cost time: 3.522275924682617
# Epoch: 9, Steps: 262 | Train Loss: 0.4071034 Vali Loss: 0.2191561 Test Loss: 0.2880097
# EarlyStopping counter: 2 out of 10
# Updating learning rate to 0.0009801468428384716
# 	iters: 100, epoch: 10 | loss: 0.2170621
# 	speed: 0.0412s/iter; left time: 978.8624s
# 	iters: 200, epoch: 10 | loss: 0.2349748
# 	speed: 0.0122s/iter; left time: 287.3355s
# Epoch: 10 cost time: 3.5029916763305664
# Epoch: 10, Steps: 262 | Train Loss: 0.3943374 Vali Loss: 0.2180313 Test Loss: 0.2892857
# EarlyStopping counter: 3 out of 10
# Updating learning rate to 0.0009755282581475768
# 	iters: 100, epoch: 11 | loss: 0.2374175
# 	speed: 0.0428s/iter; left time: 1003.9664s
# 	iters: 200, epoch: 11 | loss: 0.3016958
# 	speed: 0.0121s/iter; left time: 282.2568s
# Epoch: 11 cost time: 3.5437328815460205
# Epoch: 11, Steps: 262 | Train Loss: 0.3915677 Vali Loss: 0.2132282 Test Loss: 0.2859482
# EarlyStopping counter: 4 out of 10
# Updating learning rate to 0.0009704403844771128
# 	iters: 100, epoch: 12 | loss: 0.2342804
# 	speed: 0.0426s/iter; left time: 987.9824s
# 	iters: 200, epoch: 12 | loss: 0.3495718
# 	speed: 0.0124s/iter; left time: 287.3944s
# Epoch: 12 cost time: 3.5400173664093018
# Epoch: 12, Steps: 262 | Train Loss: 0.3886183 Vali Loss: 0.2187088 Test Loss: 0.3007092
# EarlyStopping counter: 5 out of 10
# Updating learning rate to 0.0009648882429441257
# 	iters: 100, epoch: 13 | loss: 0.1631447
# 	speed: 0.0425s/iter; left time: 976.7596s
# 	iters: 200, epoch: 13 | loss: 0.3408470
# 	speed: 0.0124s/iter; left time: 282.4122s
# Epoch: 13 cost time: 3.555718183517456
# Epoch: 13, Steps: 262 | Train Loss: 0.3862353 Vali Loss: 0.2186517 Test Loss: 0.2928095
# EarlyStopping counter: 6 out of 10
# Updating learning rate to 0.0009588773128419905
# 	iters: 100, epoch: 14 | loss: 0.3454231
# 	speed: 0.0431s/iter; left time: 978.3205s
# 	iters: 200, epoch: 14 | loss: 0.2899871
# 	speed: 0.0129s/iter; left time: 291.8620s
# Epoch: 14 cost time: 3.6545352935791016
# Epoch: 14, Steps: 262 | Train Loss: 0.3841052 Vali Loss: 0.2175227 Test Loss: 0.2917836
# EarlyStopping counter: 7 out of 10
# Updating learning rate to 0.0009524135262330098
# 	iters: 100, epoch: 15 | loss: 0.3518828
# 	speed: 0.0425s/iter; left time: 952.5768s
# 	iters: 200, epoch: 15 | loss: 0.3592884
# 	speed: 0.0124s/iter; left time: 276.7310s
# Epoch: 15 cost time: 3.5304830074310303
# Epoch: 15, Steps: 262 | Train Loss: 0.3873208 Vali Loss: 0.2169515 Test Loss: 0.2909686
# EarlyStopping counter: 8 out of 10
# Updating learning rate to 0.0009455032620941839
# 	iters: 100, epoch: 16 | loss: 0.2745466
# 	speed: 0.0414s/iter; left time: 917.6844s
# 	iters: 200, epoch: 16 | loss: 0.6065919
# 	speed: 0.0124s/iter; left time: 274.1313s
# Epoch: 16 cost time: 3.5333733558654785
# Epoch: 16, Steps: 262 | Train Loss: 0.3814456 Vali Loss: 0.2177519 Test Loss: 0.2871790
# EarlyStopping counter: 9 out of 10
# Updating learning rate to 0.0009381533400219318
# 	iters: 100, epoch: 17 | loss: 0.3816792
# 	speed: 0.0418s/iter; left time: 914.7325s
# 	iters: 200, epoch: 17 | loss: 0.3915386
# 	speed: 0.0123s/iter; left time: 268.5589s
# Epoch: 17 cost time: 3.4699835777282715
# Epoch: 17, Steps: 262 | Train Loss: 0.3791421 Vali Loss: 0.2172924 Test Loss: 0.2879910
# EarlyStopping counter: 10 out of 10
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh2_192_96_CA_MLP_ETTh2_ftM_sl192_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
#
# [PERFORMANCE] Total Inference Time: 0.3693 s
# [PERFORMANCE] Avg Inference Time / Batch: 0.004196 s
# [PERFORMANCE] Peak GPU Memory Allocated: 38.96 MB
#
# mse:0.2884504497051239, mae:0.3399693965911865, dtw:Not calculated
# Running with seq_len=336
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_336_96        Model:              CA_MLP
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            336                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       100                 Batch Size:         32
#   Patience:           10                  Learning Rate:      0.001
#   Des:                Exp_CA_MLP_researchingLoss:               MSE
#   Lradj:              cosine              Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: CA_MLP ...
# >>>>>>>start training : long_term_forecast_ETTh2_336_96_CA_MLP_ETTh2_ftM_sl336_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.7276251
# 	speed: 0.0371s/iter; left time: 949.4192s
# 	iters: 200, epoch: 1 | loss: 0.4817293
# 	speed: 0.0156s/iter; left time: 396.9218s
# Epoch: 1 cost time: 4.986435413360596
# Epoch: 1, Steps: 257 | Train Loss: 0.5694063 Vali Loss: 0.2885363 Test Loss: 0.3675543
# Validation loss decreased (inf --> 0.288536).  Saving model ...
# Updating learning rate to 0.0009997532801828658
# 	iters: 100, epoch: 2 | loss: 0.2072633
# 	speed: 0.0516s/iter; left time: 1308.2849s
# 	iters: 200, epoch: 2 | loss: 0.5345442
# 	speed: 0.0158s/iter; left time: 399.3848s
# Epoch: 2 cost time: 4.360587120056152
# Epoch: 2, Steps: 257 | Train Loss: 0.4324866 Vali Loss: 0.2232011 Test Loss: 0.2837979
# Validation loss decreased (0.288536 --> 0.223201).  Saving model ...
# Updating learning rate to 0.0009990133642141358
# 	iters: 100, epoch: 3 | loss: 0.4075218
# 	speed: 0.0527s/iter; left time: 1321.1249s
# 	iters: 200, epoch: 3 | loss: 0.5432766
# 	speed: 0.0159s/iter; left time: 397.3652s
# Epoch: 3 cost time: 4.465352773666382
# Epoch: 3, Steps: 257 | Train Loss: 0.3995366 Vali Loss: 0.2363047 Test Loss: 0.2794990
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 0.00099778098230154
# 	iters: 100, epoch: 4 | loss: 0.4110966
# 	speed: 0.0524s/iter; left time: 1300.3341s
# 	iters: 200, epoch: 4 | loss: 0.3413371
# 	speed: 0.0158s/iter; left time: 391.6733s
# Epoch: 4 cost time: 4.39359188079834
# Epoch: 4, Steps: 257 | Train Loss: 0.3890362 Vali Loss: 0.2325341 Test Loss: 0.2798162
# EarlyStopping counter: 2 out of 10
# Updating learning rate to 0.000996057350657239
# 	iters: 100, epoch: 12 | loss: 0.3746440
# 	speed: 0.0518s/iter; left time: 1179.7065s
# 	iters: 200, epoch: 12 | loss: 0.2590809
# 	speed: 0.0159s/iter; left time: 359.5674s
# Epoch: 12 cost time: 4.411689519882202
# Epoch: 12, Steps: 257 | Train Loss: 0.3671307 Vali Loss: 0.2285090 Test Loss: 0.2867998
# EarlyStopping counter: 4 out of 10
# Updating learning rate to 0.0009648882429441257
# 	iters: 100, epoch: 13 | loss: 0.2124199
# 	speed: 0.0526s/iter; left time: 1183.4258s
# 	iters: 200, epoch: 13 | loss: 0.4227086
# 	speed: 0.0159s/iter; left time: 357.3275s
# Epoch: 13 cost time: 4.425232887268066
# Epoch: 13, Steps: 257 | Train Loss: 0.3652402 Vali Loss: 0.2455616 Test Loss: 0.3003325
# EarlyStopping counter: 5 out of 10
# Updating learning rate to 0.0009588773128419905
# 	iters: 100, epoch: 14 | loss: 0.3984390
# 	speed: 0.0524s/iter; left time: 1167.0136s
# 	iters: 200, epoch: 14 | loss: 0.5131849
# 	speed: 0.0155s/iter; left time: 343.7255s
# Epoch: 14 cost time: 4.371564865112305
# Epoch: 14, Steps: 257 | Train Loss: 0.3636535 Vali Loss: 0.2243211 Test Loss: 0.2909094
# EarlyStopping counter: 6 out of 10
# Updating learning rate to 0.0009524135262330098
# 	iters: 100, epoch: 15 | loss: 0.5286724
# 	speed: 0.0522s/iter; left time: 1147.5671s
# 	iters: 200, epoch: 15 | loss: 0.4579349
# 	speed: 0.0159s/iter; left time: 348.5742s
# Epoch: 15 cost time: 4.432964086532593
# Epoch: 15, Steps: 257 | Train Loss: 0.3633504 Vali Loss: 0.2267867 Test Loss: 0.2881424
# EarlyStopping counter: 7 out of 10
# Updating learning rate to 0.0009455032620941839
# 	iters: 100, epoch: 16 | loss: 0.2462886
# 	speed: 0.0521s/iter; left time: 1132.2067s
# 	iters: 200, epoch: 16 | loss: 0.3123803
# 	speed: 0.0160s/iter; left time: 347.0952s
# Epoch: 16 cost time: 4.411898851394653
# Epoch: 16, Steps: 257 | Train Loss: 0.3609112 Vali Loss: 0.2326868 Test Loss: 0.2961113
# EarlyStopping counter: 8 out of 10
# Updating learning rate to 0.0009381533400219318
# 	iters: 100, epoch: 17 | loss: 0.2719905
# 	speed: 0.0525s/iter; left time: 1128.3192s
# 	iters: 200, epoch: 17 | loss: 0.3387899
# 	speed: 0.0160s/iter; left time: 341.8045s
# Epoch: 17 cost time: 4.415919542312622
# Epoch: 17, Steps: 257 | Train Loss: 0.3609728 Vali Loss: 0.2339537 Test Loss: 0.2908175
# EarlyStopping counter: 9 out of 10
# Updating learning rate to 0.0009303710135019718
# 	iters: 100, epoch: 18 | loss: 0.4199386
# 	speed: 0.0519s/iter; left time: 1102.8529s
# 	iters: 200, epoch: 18 | loss: 0.4895207
# 	speed: 0.0156s/iter; left time: 330.1309s
# Epoch: 18 cost time: 4.382120847702026
# Epoch: 18, Steps: 257 | Train Loss: 0.3594113 Vali Loss: 0.2236165 Test Loss: 0.2871914
# EarlyStopping counter: 10 out of 10
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh2_336_96_CA_MLP_ETTh2_ftM_sl336_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
#
# [PERFORMANCE] Total Inference Time: 0.5715 s
# [PERFORMANCE] Avg Inference Time / Batch: 0.006495 s
# [PERFORMANCE] Peak GPU Memory Allocated: 54.70 MB
#
# mse:0.28223392367362976, mae:0.33954736590385437, dtw:Not calculated
# Running with seq_len=512
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_512_96        Model:              CA_MLP
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       100                 Batch Size:         32
#   Patience:           10                  Learning Rate:      0.001
#   Des:                Exp_CA_MLP_researchingLoss:               MSE
#   Lradj:              cosine              Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: CA_MLP ...
# >>>>>>>start training : long_term_forecast_ETTh2_512_96_CA_MLP_ETTh2_ftM_sl512_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8033
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.5102185
# 	speed: 0.0431s/iter; left time: 1082.4361s
# 	iters: 200, epoch: 1 | loss: 0.8126262
# 	speed: 0.0221s/iter; left time: 552.7142s
# Epoch: 1 cost time: 6.5239012241363525
# Epoch: 1, Steps: 252 | Train Loss: 0.6186352 Vali Loss: 0.3029934 Test Loss: 0.3583171
# Validation loss decreased (inf --> 0.302993).  Saving model ...
# Updating learning rate to 0.0009997532801828658
# 	iters: 100, epoch: 2 | loss: 0.5635502
# 	speed: 0.0670s/iter; left time: 1665.9629s
# 	iters: 200, epoch: 2 | loss: 0.5721766
# 	speed: 0.0225s/iter; left time: 556.0675s
# Epoch: 2 cost time: 5.986901521682739
# Epoch: 2, Steps: 252 | Train Loss: 0.4415124 Vali Loss: 0.2237559 Test Loss: 0.2785790
# Validation loss decreased (0.302993 --> 0.223756).  Saving model ...
# Updating learning rate to 0.0009990133642141358
# 	iters: 100, epoch: 3 | loss: 0.8166890
# 	speed: 0.0687s/iter; left time: 1689.7142s
# 	iters: 200, epoch: 3 | loss: 0.3145169
# 	speed: 0.0228s/iter; left time: 557.7522s
# Epoch: 3 cost time: 6.061007738113403
# Epoch: 3, Steps: 252 | Train Loss: 0.4042795 Vali Loss: 0.2300428 Test Loss: 0.2728218
# EarlyStopping counter: 1 out of 10
# Updating learning rate to
# 	iters: 100, epoch: 17 | loss: 0.2279667
# 	speed: 0.0677s/iter; left time: 1426.5888s
# 	iters: 200, epoch: 17 | loss: 0.3014833
# 	speed: 0.0223s/iter; left time: 467.2868s
# Epoch: 17 cost time: 5.970150470733643
# Epoch: 17, Steps: 252 | Train Loss: 0.3587577 Vali Loss: 0.2234775 Test Loss: 0.2786408
# EarlyStopping counter: 10 out of 10
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh2_512_96_CA_MLP_ETTh2_ftM_sl512_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
#
# [PERFORMANCE] Total Inference Time: 0.8436 s
# [PERFORMANCE] Avg Inference Time / Batch: 0.009586 s
# [PERFORMANCE] Peak GPU Memory Allocated: 74.01 MB
#
# mse:0.27482885122299194, mae:0.33311814069747925, dtw:Not calculated
# Running with seq_len=720
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_720_96        Model:              CA_MLP
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            720                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               32
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       100                 Batch Size:         32
#   Patience:           10                  Learning Rate:      0.001
#   Des:                Exp_CA_MLP_researchingLoss:               MSE
#   Lradj:              cosine              Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: CA_MLP ...
# >>>>>>>start training : long_term_forecast_ETTh2_720_96_CA_MLP_ETTh2_ftM_sl720_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7825
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.5817657
# 	speed: 0.0514s/iter; left time: 1254.0789s
# 	iters: 200, epoch: 1 | loss: 0.5421854
# 	speed: 0.0304s/iter; left time: 738.6723s
# Epoch: 1 cost time: 8.37220573425293
# Epoch: 1, Steps: 245 | Train Loss: 0.6363170 Vali Loss: 0.2985751 Test Loss: 0.3614701
# Validation loss decreased (inf --> 0.298575).  Saving model ...
# Updating learning rate to 0.0009997532801828658
# 	iters: 100, epoch: 2 | loss: 0.3443491
# 	speed: 0.0852s/iter; left time: 2057.6123s
# 	speed: 0.0845s/iter; left time: 1751.0747s
# 	iters: 200, epoch: 16 | loss: 0.4042575
# 	speed: 0.0306s/iter; left time: 631.0294s
# Epoch: 16 cost time: 7.794276237487793
# Epoch: 16, Steps: 245 | Train Loss: 0.3747696 Vali Loss: 0.2236849 Test Loss: 0.2714749
# EarlyStopping counter: 5 out of 10
# Updating learning rate to 0.0009381533400219318
# 	iters: 100, epoch: 17 | loss: 0.5267344
# 	speed: 0.0848s/iter; left time: 1736.4252s
# 	iters: 200, epoch: 17 | loss: 0.2891766
# 	speed: 0.0306s/iter; left time: 624.6111s
# Epoch: 17 cost time: 7.828779935836792
# Epoch: 17, Steps: 245 | Train Loss: 0.3724151 Vali Loss: 0.2317065 Test Loss: 0.2754227
# EarlyStopping counter: 6 out of 10
# Updating learning rate to 0.0009303710135019718
# 	iters: 100, epoch: 18 | loss: 0.2603774
# 	speed: 0.0849s/iter; left time: 1718.4486s
# 	iters: 200, epoch: 18 | loss: 0.1947883
# 	speed: 0.0306s/iter; left time: 616.4904s
# Epoch: 18 cost time: 7.8483264446258545
# Epoch: 18, Steps: 245 | Train Loss: 0.3716692 Vali Loss: 0.2203167 Test Loss: 0.2751517
# EarlyStopping counter: 7 out of 10
# Updating learning rate to 0.0009221639627510075
# 	iters: 100, epoch: 19 | loss: 0.9114900
# 	speed: 0.0849s/iter; left time: 1698.1860s
# 	iters: 200, epoch: 19 | loss: 0.2877110
# 	speed: 0.0306s/iter; left time: 608.1155s
# Epoch: 19 cost time: 7.8399224281311035
# Epoch: 19, Steps: 245 | Train Loss: 0.3696499 Vali Loss: 0.2247606 Test Loss: 0.2702128
# EarlyStopping counter: 8 out of 10
# Updating learning rate to 0.0009135402871372809
# 	iters: 100, epoch: 20 | loss: 0.4681607
# 	speed: 0.0843s/iter; left time: 1663.7276s
# 	iters: 200, epoch: 20 | loss: 0.5501484
# 	speed: 0.0306s/iter; left time: 601.0882s
# Epoch: 20 cost time: 7.815426826477051
# Epoch: 20, Steps: 245 | Train Loss: 0.3702252 Vali Loss: 0.2277904 Test Loss: 0.2740831
# EarlyStopping counter: 9 out of 10
# Updating learning rate to 0.0009045084971874737
# 	iters: 100, epoch: 21 | loss: 0.3447340
# 	speed: 0.0850s/iter; left time: 1656.9725s
# 	iters: 200, epoch: 21 | loss: 0.3244943
# 	speed: 0.0307s/iter; left time: 595.5530s
# Epoch: 21 cost time: 7.8365702629089355
# Epoch: 21, Steps: 245 | Train Loss: 0.3680676 Vali Loss: 0.2349128 Test Loss: 0.2729140
# EarlyStopping counter: 10 out of 10
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh2_720_96_CA_MLP_ETTh2_ftM_sl720_ll0_pl96_dm16_nh4_el3_dl1_df32_expand2_dc4_fc1_ebtimeF_dtTrue_Exp_CA_MLP_researching_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
#
# [PERFORMANCE] Total Inference Time: 1.1557 s
# [PERFORMANCE] Avg Inference Time / Batch: 0.013133 s
# [PERFORMANCE] Peak GPU Memory Allocated: 97.77 MB
#
# mse:0.27434128522872925, mae:0.3373395502567291, dtw:Not calculated
