# %%
# !pip install -r '/kaggle/input/datasets/hoangbonduy/ca-mlp-ablation/CA-MLP/requirements_TimeKAN.txt'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 73.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 48.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.8/159.8 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 110.0 MB/s eta 0:00:00
# ...

# %%
import os

# 1. Copy toàn bộ thư mục code sang /kaggle/working/ (nơi có quyền ghi/sửa)
# !cp -r /kaggle/input/datasets/hoangbonduy/ca-mlp-ablation/CA-MLP /kaggle/working/JD-KAN_writable

# 2. Chuyển thư mục làm việc sang thư mục vừa copy
os.chdir('/kaggle/working/JD-KAN_writable')

# Kiểm tra xem đã đúng thư mục chưa (Đường dẫn hiện tại sẽ là /kaggle/working/...)
# !pwd
# !ls
# Out:
# /kaggle/working/JD-KAN_writable
# checkpoints    exp		   KQ	   README.md		     run.py
# data_provider  experiment_figures  layers  requirements_TimeKAN.txt  scripts
# dataset        experiment_scripts  models  requirements.txt	     utils

# %% [markdown]
# Etth1

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth1/etth1_96.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth1/etth1_96.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth1/etth1_96.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_96_96         Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth1/etth1_192.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth1/etth1_192.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth1/etth1_192.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_96_192        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           192                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth1/etth1_336.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth1/etth1_336.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth1/etth1_336.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_96_336        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           336                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth1/etth1_720.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth1/etth1_720.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth1/etth1_720.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_96_720        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           720                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %% [markdown]
# Etth2

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth2/etth2_96.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth2/etth2_96.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth2/etth2_96.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_96_96         Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth2/etth2_192.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth2/etth2_192.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth2/etth2_192.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_96_192        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           192                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth2/etth2_336.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth2/etth2_336.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth2/etth2_336.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_96_336        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           336                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Etth2/etth2_720.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Etth2/etth2_720.sh

# 3. Chạy script
# !./scripts/noconv1d/Etth2/etth2_720.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh2_96_720        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTh2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTh2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           720                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           3
# ...

# %% [markdown]
# Ettm1

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm1/ettm1_96.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm1/ettm1_96.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm1/ettm1_96.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm1_96_96         Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            8                   e layers:           2
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm1/ettm1_192.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm1/ettm1_192.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm1/ettm1_192.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm1_96_192        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           192                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm1/ettm1_336.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm1/ettm1_336.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm1/ettm1_336.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm1_96_336        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           336                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm1/ettm1_720.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm1/ettm1_720.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm1/ettm1_720.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm1_96_720        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm1               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           720                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...

# %% [markdown]
# Ettm2

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm2/ettm2_96.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm2/ettm2_96.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm2/ettm2_96.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm2_96_96         Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm2/ettm2_192.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm2/ettm2_192.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm2/ettm2_192.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm2_96_192        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           192                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm2/ettm2_336.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm2/ettm2_336.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm2/ettm2_336.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm2_96_336        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           336                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...

# %%
# 1. Chuyển đổi định dạng xuống dòng (nếu file được tạo trên Windows, bước này giúp tránh lỗi cú pháp)
# !sed -i 's/\r$//' scripts/noconv1d/Ettm2/ettm2_720.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/noconv1d/Ettm2/ettm2_720.sh

# 3. Chạy script
# !./scripts/noconv1d/Ettm2/ettm2_720.sh
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTm2_96_720        Model:              CA_MLP_noconv1d
#
# Data Loader
#   Data:               ETTm2               Root Path:          ./dataset/ETT-small/
#   Data Path:          ETTm2.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          0
#   Pred Len:           720                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            16
#   n heads:            4                   e layers:           2
# ...
